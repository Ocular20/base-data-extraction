# %%
import pandas as pd

# %%
#https://stats.oecd.org/viewhtml.aspx?datasetcode=MEI_FIN&lang=en#

# %%
df = pd.read_csv(r'C:\Users\ROSHAN\Fornax Internship\MEI_FIN_08082020144250062.csv')

df1 = pd.read_csv(r'C:\Users\ROSHAN\Fornax Internship\MEI_FIN_08082020150235628.csv')

df2 = pd.read_csv(r'C:\Users\ROSHAN\Fornax Internship\MEI_FIN_08082020150658237.csv')

df3 = pd.read_csv(r'C:\Users\ROSHAN\Fornax Internship\MEI_FIN_08082020151835725.csv')

# %%
df.head()
# Out:
#   SUBJECT                                   Subject LOCATION Country  \
# 0    CCUS  Currency exchange rates, monthly average      IND   India
# 1    CCUS  Currency exchange rates, monthly average      IND   India
# 2    CCUS  Currency exchange rates, monthly average      IND   India
# 3    CCUS  Currency exchange rates, monthly average      IND   India
# 4    CCUS  Currency exchange rates, monthly average      IND   India
#
#   FREQUENCY Frequency  TIME  Time Unit Code                             Unit  \
# 0         A    Annual  1957  1957    NATUSD  National currency per US dollar
# 1         A    Annual  1958  1958    NATUSD  National currency per US dollar
# 2         A    Annual  1959  1959    NATUSD  National currency per US dollar
# 3         A    Annual  1960  1960    NATUSD  National currency per US dollar
# 4         A    Annual  1961  1961    NATUSD  National currency per US dollar
#
#    PowerCode Code PowerCode  Reference Period Code  Reference Period  \
# ...

# %%
df1.head()
# Out:
#   SUBJECT                                   Subject LOCATION Country  \
# 0    CCUS  Currency exchange rates, monthly average      IND   India
# 1    CCUS  Currency exchange rates, monthly average      IND   India
# 2    CCUS  Currency exchange rates, monthly average      IND   India
# 3    CCUS  Currency exchange rates, monthly average      IND   India
# 4    CCUS  Currency exchange rates, monthly average      IND   India
#
#   FREQUENCY Frequency  TIME  Time Unit Code                             Unit  \
# 0         A    Annual  1957  1957    NATUSD  National currency per US dollar
# 1         A    Annual  1958  1958    NATUSD  National currency per US dollar
# 2         A    Annual  1959  1959    NATUSD  National currency per US dollar
# 3         A    Annual  1960  1960    NATUSD  National currency per US dollar
# 4         A    Annual  1961  1961    NATUSD  National currency per US dollar
#
#    PowerCode Code PowerCode  Reference Period Code  Reference Period  \
# ...

# %%
df2.head()
# Out:
#   SUBJECT                                   Subject LOCATION Country  \
# 0    CCUS  Currency exchange rates, monthly average      IND   India
# 1    CCUS  Currency exchange rates, monthly average      IND   India
# 2    CCUS  Currency exchange rates, monthly average      IND   India
# 3    CCUS  Currency exchange rates, monthly average      IND   India
# 4    CCUS  Currency exchange rates, monthly average      IND   India
#
#   FREQUENCY Frequency  TIME  Time Unit Code                             Unit  \
# 0         A    Annual  1957  1957    NATUSD  National currency per US dollar
# 1         A    Annual  1958  1958    NATUSD  National currency per US dollar
# 2         A    Annual  1959  1959    NATUSD  National currency per US dollar
# 3         A    Annual  1960  1960    NATUSD  National currency per US dollar
# 4         A    Annual  1961  1961    NATUSD  National currency per US dollar
#
#    PowerCode Code PowerCode  Reference Period Code  Reference Period  \
# ...

# %%
df.to_csv('Long-Term Interest Rates(Per Cent Per Annum).csv' , index = False)

# %%
df1.to_csv('Short-Term Interest Rates(Per Cent Per Annum).csv' , index = False)

# %%
df2.to_csv('Immediate Interest Rates,Call Money,Interbank Rate(Per Cent Per Annum).csv' , index = False)

# %%
df3.to_csv('Currency Exhange Rate(Per Cent Per Annum).csv' , index = False)

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\ROSHAN\Fornax Internship\MEI_REAL_08082020153102955.csv')

df1 = pd.read_csv(r'C:\Users\ROSHAN\Fornax Internship\Production & Sales\MEI_REAL_08082020155928788.csv')

# %%
df.head()
# Out:
#     SUBJECT                                 Subject LOCATION Country  \
# 0  PRINTO01  Production of total industry sa, Index      IND   India
# 1  PRINTO01  Production of total industry sa, Index      IND   India
# 2  PRINTO01  Production of total industry sa, Index      IND   India
# 3  PRINTO01  Production of total industry sa, Index      IND   India
# 4  PRINTO01  Production of total industry sa, Index      IND   India
#
#   FREQUENCY Frequency  TIME  Time Unit Code   Unit  PowerCode Code PowerCode  \
# 0         A    Annual  1995  1995       IDX  Index               0     Units
# 1         A    Annual  1996  1996       IDX  Index               0     Units
# 2         A    Annual  1997  1997       IDX  Index               0     Units
# 3         A    Annual  1998  1998       IDX  Index               0     Units
# 4         A    Annual  1999  1999       IDX  Index               0     Units
#
#   Reference Period Code Reference Period     Value Flag Codes Flags
# ...

# %%
df1.head()
# Out:
#     SUBJECT                                 Subject LOCATION Country  \
# 0  PRINTO01  Production of total industry sa, Index      IND   India
# 1  PRINTO01  Production of total industry sa, Index      IND   India
# 2  PRINTO01  Production of total industry sa, Index      IND   India
# 3  PRINTO01  Production of total industry sa, Index      IND   India
# 4  PRINTO01  Production of total industry sa, Index      IND   India
#
#   FREQUENCY Frequency  TIME  Time Unit Code   Unit  PowerCode Code PowerCode  \
# 0         A    Annual  1995  1995       IDX  Index               0     Units
# 1         A    Annual  1996  1996       IDX  Index               0     Units
# 2         A    Annual  1997  1997       IDX  Index               0     Units
# 3         A    Annual  1998  1998       IDX  Index               0     Units
# 4         A    Annual  1999  1999       IDX  Index               0     Units
#
#   Reference Period Code Reference Period     Value Flag Codes Flags
# ...

# %%
df.to_csv('Production of total industry - India.csv' , index = False)

# %%
df1.to_csv('Production in total manufacturing - India.csv' , index = False)

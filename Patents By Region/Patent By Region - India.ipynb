# %%
import pandas as pd

# %%
#https://stats.oecd.org/viewhtml.aspx?datasetcode=PATS_REGION&lang=en#

#Patent applications to the European Patent Office (EPO) (from 1978 onwards);
#Patents filed under the Patent Co-operation Treaty (PCT), at international phase, that designate the EPO (from 1978 onwards);

# %%
df = pd.read_csv(r'C:\Users\ROSHAN\Fornax Internship\Patents By Region\PATS_REGION_08082020163204236.csv')

# %%
df.head()
# Out:
#   KINDPATENT                   Patent office KINDREGION  \
# 0      EPO_A  Patent applications to the EPO  INVENTORS
# 1      EPO_A  Patent applications to the EPO  INVENTORS
# 2      EPO_A  Patent applications to the EPO  INVENTORS
# 3      EPO_A  Patent applications to the EPO  INVENTORS
# 4      EPO_A  Patent applications to the EPO  INVENTORS
#
#                           Reference region REGIONS Regions TECHNO  \
# 0  Inventor(s)'s country(ies) of residence     IND   India  TOTAL
# 1  Inventor(s)'s country(ies) of residence     IND   India  TOTAL
# 2  Inventor(s)'s country(ies) of residence     IND   India  TOTAL
# 3  Inventor(s)'s country(ies) of residence     IND   India  TOTAL
# 4  Inventor(s)'s country(ies) of residence     IND   India  TOTAL
#
#   Total patents and by technologies  TIME  Time Unit Code    Unit  \
# 0                     Total Patents  1977  1977       NBR  Number
# 1                     Total Patents  1978  1978       NBR  Number
# ...

# %%
df.to_csv('Patent By Region - India.csv' , index = False)
